# %% [markdown]
# # Initialize

# %%
import requests as rq
import pandas as pd
import json
import time
import os

# %% [markdown]
# # Get Data

# %%
def get_data(acc):
    global player_data

    key = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiIsImtpZCI6IjI4YTMxOGY3LTAwMDAtYTFlYi03ZmExLTJjNzQzM2M2Y2NhNSJ9..-VrtyZRK_8c8EBwRL4Qp2KV3k70Pnyxq-WfItjsebHKf9DgHhoEiKWLfQtSo43Z72tzW9wB4cnnsqDAv6jJedQ'
    player = [
        '%23JQRYG2UL',
        '%23G2PGY2GGO'
    ]
    headers = {
        'Accept': 'application/json',
        'authorization': 'Bearer %s' % key
    }

    response = rq.request('GET', 'https://api.clashofclans.com/v1/players/' + player[acc - 1], headers = headers)
    player_data = response.json()
    
    get_player_achievements()
    get_troop_data()

# %% [markdown]
# # Get Achievements

# %%
def get_player_achievements():
    global player_data
    dfs = []
    achievements = {}
    csv = r'C:\Users\juliu\Documents\Work\Python\CoC Files\player_data.csv'

    for achv in player_data['achievements']:
        if achv['name'] == 'Gold Grab':
            achievements[achv['name']] =  achv['value']
        elif achv['name'] == 'Elixir Escapade':
            achievements[achv['name']] =  achv['value']
        elif achv['name'] == 'Heroic Heist':
            achievements[achv['name']] =  achv['value']

    dfs.append(pd.DataFrame([achievements]))
    df = pd.concat(dfs, ignore_index=True, sort=False)
    df['Tag'] = player_data['tag']
    df['Name'] = player_data['name']
    df['Town Hall Level'] = player_data['townHallLevel']
    df['Trophies'] = player_data['trophies']
    df['Builder Hall Level'] = player_data['builderHallLevel']
    df['Builder Base Trophies'] = player_data['builderBaseTrophies']
    df['Donations'] = player_data['donations']
    df['Donations Received'] = player_data['donationsReceived']
    
    for coln in dfs[0].columns:
        df = df[[col for col in df.columns if col != coln] + [coln]]

    df['Timestamp'] = pd.Timestamp.now()

    if not os.path.isfile(csv):
        df.to_csv(csv, header = 'column_names', index = False)
    else:
        df.to_csv(csv, mode = 'a', header = False, index = False)

# %% [markdown]
# # Get Troop Data

# %%
def get_troop_data():
    global player_data
    dfs2 = []
    csv2 = r'C:\Users\juliu\Documents\Work\Python\CoC Files\troop_data.csv'
    
    dfs2.append(pd.DataFrame(player_data['troops']))
    dfs2.append(pd.DataFrame(player_data['heroes']))
    dfs2.append(pd.DataFrame(player_data['spells']))
    df2 = pd.concat(dfs2, ignore_index=True, sort=False)
    df2['Tag'] = player_data['tag']
    df2['Timestamp'] = pd.Timestamp.now()
    
    df2 = df2[['Tag'] + [col for col in df2.columns if col != 'Tag']]

    if not os.path.isfile(csv2):
        df2.to_csv(csv2, header = 'column_names', index = False)
    else:
        df2.to_csv(csv2, mode = 'a', header = False, index = False)

# %%
os.remove(r'C:\Users\juliu\Documents\Work\Python\CoC Files\troop_data.csv')
get_data(1)
get_data(2)

# %% [markdown]
# # Get Player Data

# %%
while(True):
    os.remove(r'C:\Users\juliu\Documents\Work\Python\CoC Files\troop_data.csv')
    get_data(1)
    get_data(2)
    time.sleep(86400)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 while(True):
# ----> 2     get_data(1)
#       3     get_data(2)
#       4     time.sleep(86400)
#
# NameError: name 'get_data' is not defined

# %% [markdown]
# # Get Clan Data

# %%
clan = 'https://api.clashofclans.com/v1/clan/%232Q29CYYRR'

response = rq.request('GET', clan, headers = headers)

clan_data = response.json()

clan_data_indent = json.dumps(clan_data, indent = 3)

print(clan_data_indent)
# Out:
# {
#    "tag": "#JQRYG2UL",
#    "name": "juls",
#    "townHallLevel": 12,
#    "townHallWeaponLevel": 5,
#    "expLevel": 161,
#    "trophies": 3904,
#    "bestTrophies": 3947,
#    "warStars": 429,
#    "attackWins": 104,
#    "defenseWins": 2,
#    "builderHallLevel": 8,
#    "builderBaseTrophies": 2721,
#    "versusTrophies": 2721,
#    "bestBuilderBaseTrophies": 3038,
#    "bestVersusTrophies": 3038,
#    "versusBattleWins": 0,
#    "role": "leader",
#    "warPreference": "out",
#    "donations": 6370,
#    "donationsReceived": 3255,
#    "clanCapitalContributions": 0,
#    "clan": {
#       "tag": "#2Q29CYYRR",
#       "name": "S\u00f8L\u00f8",
#       "clanLevel": 1,
#       "badgeUrls": {
#          "small": "https://api-assets.clashofclans.com/badges/70/cwUU5isd0Q6l9WYxSWE8kJXNvsPD0voXcecrDYukkuA.png",
#          "large": "https://api-assets.clashofclans.com/badges/512/cwUU5isd0Q6l9WYxSWE8kJXNvsPD0voXcecrDYukkuA.png",
# ...
